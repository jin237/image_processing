# %%
import cv2
from PIL import Image


img = Image.open('/Users/jin237/Documents/image_processing/japanese_pro.png')
img_resize_lanczos = img.resize((450, 300), Image.LANCZOS)
img_resize_lanczos.save('japanese_pro.png')

# %%
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

#画像の読み込み
beautiful_view = Image.open("/Users/jin237/Documents/image_processing/japanese_pro.png")

#画像を表示して確認
plt.imshow(beautiful_view)

#画像のリサイズ
small_beautiful_view = beautiful_view.resize((450, 300))

#リサイズした画像を表示して確認
plt.imshow(small_beautiful_view)

#リサイズした画像を名前をつけて保存
small_beautiful_view.save("japanese_pro.png")

# %%
import cv2
img = cv2.imread('/Users/jin237/Documents/image_processing/friction_spectrum.png')
height = img.shape[0]
width = img.shape[1]
img2 = cv2.resize(img , (int(width*0.5), int(height*0.5)))
cv2.imwrite('./data/pict/image2.jpg' , img2)
# Out:
# False
